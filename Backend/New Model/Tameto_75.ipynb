# %% [markdown]
# **Importing Dataset**

# %%
from google.colab import drive

# %%
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# **Main**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

import keras
from keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img 
from keras.applications.vgg19 import VGG19, preprocess_input, decode_predictions

# %%
train_datagen = ImageDataGenerator(zoom_range= 0.5, shear_range= 0.3, horizontal_flip= True, preprocessing_function = preprocess_input)
val_datagen = ImageDataGenerator(preprocessing_function = preprocess_input)

# %%
train = train_datagen.flow_from_directory(directory= "/content/drive/MyDrive/Dataset/Tameto 2.0/train", target_size=(256,256), batch_size=32 )

val = val_datagen.flow_from_directory(directory= "/content/drive/MyDrive/Dataset/Tameto 2.0/val", target_size=(256,256), batch_size=32 )
# Out:
# Found 10000 images belonging to 10 classes.
# Found 1000 images belonging to 10 classes.

# %% [markdown]
# **Testing Image**

# %%
t_img , label = train.next()

# %%
def plotImage(img_arr, label):

  for im , l in zip(img_arr , label):
    plt.figure(figsize=(5,5)) 
    plt.imshow(im)
    plt.show()

# %%
plotImage(t_img[:3],label[:3])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# **Model**

# %%
from keras.layers import Dense, Flatten
from keras.models import Model
from keras.applications.vgg19 import VGG19
import keras

# %%
base_model = VGG19(input_shape=(256, 256,3), include_top= False)
# Out:
# ...
# 80150528/80134624 [==============================] - 1s 0us/step

# %%
for layer in base_model.layers:
  layer.trainable = False

# %%
X = X = Flatten() (base_model.output)
X = Dense (units= 10, activation='softmax')(X)

model = Model(base_model.input, X)

# %%
model.compile(optimizer= 'adam' , loss= keras.losses.categorical_crossentropy, metrics= ['accuracy'])

# %% [markdown]
# **Early Stopping and Model Checkpoints**

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping

es = EarlyStopping(monitor= 'val_accuracy', min_delta= 0.01, patience= 3, verbose=1)

mc = ModelCheckpoint(filepath="best_model.h5",
                    monitor= 'val_accuracy',
                    min_delta= 0.01,
                    patience= 3,
                    verbose=1 ,
                    save_best_only= True)

cb = [es,mc]

# %%
his = model.fit(train ,
                steps_per_epoch= 16,
                epochs= 50,
                verbose= 1,
                callbacks= cb ,
                validation_data= val ,
                validation_steps= 16)
# Out:
# Epoch 1/50
# 16/16 [==============================] - 860s 55s/step - loss: 13.4735 - accuracy: 0.3457 - val_loss: 15.0100 - val_accuracy: 0.4785
#
# Epoch 00001: val_accuracy improved from -inf to 0.47852, saving model to best_model.h5
# Epoch 2/50
# 16/16 [==============================] - 841s 54s/step - loss: 7.6777 - accuracy: 0.5766 - val_loss: 12.6623 - val_accuracy: 0.5332
#
# Epoch 00002: val_accuracy improved from 0.47852 to 0.53320, saving model to best_model.h5
# Epoch 3/50
# 16/16 [==============================] - 851s 54s/step - loss: 6.8936 - accuracy: 0.6328 - val_loss: 8.2862 - val_accuracy: 0.6152
#
# Epoch 00003: val_accuracy improved from 0.53320 to 0.61523, saving model to best_model.h5
# Epoch 4/50
# 16/16 [==============================] - 849s 54s/step - loss: 5.6083 - accuracy: 0.6758 - val_loss: 6.7330 - val_accuracy: 0.6973
#
# Epoch 00004: val_accuracy improved from 0.61523 to 0.69727, saving model to best_model.h5
# Epoch 5/50
# ...

# %% [markdown]
# **Graphs**

# %%
h = his.history
h.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot (h['accuracy'])
plt.plot (h['val_accuracy'], c = "red")
plt.title("acc vs v-acc")
plt.show()

# %%
plt.plot(h['loss'])
plt.plot (h['val_loss'], c = "red")
plt.title("loss vs v-loss")
plt.show()

# %% [markdown]
# **Importing Model and Prediction**

# %%
from keras.models import load_model

model = load_model("/content/best_model.h5")

# %%
dict(zip( list(train.class_indices.values()) , list(train.class_indices.keys()) ) )
# Out:
# {0: 'Tomato___Bacterial_spot',
#  1: 'Tomato___Early_blight',
#  2: 'Tomato___Late_blight',
#  3: 'Tomato___Leaf_Mold',
#  4: 'Tomato___Septoria_leaf_spot',
#  5: 'Tomato___Spider_mites Two-spotted_spider_mite',
#  6: 'Tomato___Target_Spot',
#  7: 'Tomato___Tomato_Yellow_Leaf_Curl_Virus',
#  8: 'Tomato___Tomato_mosaic_virus',
#  9: 'Tomato___healthy'}

# %%
def prediction(path):
  img = load_img(path, target_size = (256,256))
  i = img_to_array(img)
  im = preprocess_input(i)
  img = np.expand_dims(im , axis= 0)
  pred = np.argmax(model.predict(img))
  print(f" the image belongs to { ref[pred] } ")
  print(model.predict(img))

# %%
path = "/content/leaf_mold_tomato3x1200.jpg"

prediction(path)
# Out:
#  the image belongs to Tomato___Late_blight
# [[0.0000000e+00 6.2643135e-14 9.4723177e-01 5.2768242e-02 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 9.5778446e-29 0.0000000e+00 0.0000000e+00]]
