# %% [markdown]
# **Importing Dataset**

# %%
from google.colab import drive

# %%
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

import keras
from keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img 
from keras.applications.vgg19 import VGG19, preprocess_input, decode_predictions

# %% [markdown]
# **Preprocessing Data**

# %%
train_datagen = ImageDataGenerator(zoom_range= 0.5, shear_range= 0.3, horizontal_flip= True, preprocessing_function = preprocess_input)
val_datagen = ImageDataGenerator(preprocessing_function = preprocess_input)

# %%
train = train_datagen.flow_from_directory(directory= "/content/drive/MyDrive/Dataset/apple/train", target_size=(256,256), batch_size=32 )

val = val_datagen.flow_from_directory(directory= "/content/drive/MyDrive/Dataset/apple/valid", target_size=(256,256), batch_size=32 )
# Out:
# Found 7771 images belonging to 4 classes.
# Found 1943 images belonging to 4 classes.

# %% [markdown]
# **Visualising Data**

# %%
t_img , label = train.next()

# %%
def plotImage(img_arr, label):

  for im , l in zip(img_arr , label):
    plt.figure(figsize=(5,5)) 
    plt.imshow(im)
    plt.show()

# %%
plotImage(t_img[:3],label[:3])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# **Model**

# %%
from keras.layers import Dense, Flatten
from keras.models import Model
from keras.applications.vgg19 import VGG19
import keras

# %%
base_model = VGG19(input_shape=(256, 256,3), include_top= False)
# Out:
# ...
# 80150528/80134624 [==============================] - 1s 0us/step

# %%
for layer in base_model.layers:
  layer.trainable = False

# %%
X = Flatten() (base_model.output)
X = Dense (units= 4, activation='softmax')(X)

model = Model(base_model.input, X)

# %%
model.compile(optimizer= 'adam' , loss= keras.losses.categorical_crossentropy, metrics= ['accuracy'])

# %% [markdown]
# **Early Stopping and Model Checkpoints**

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping

es = EarlyStopping(monitor= 'val_accuracy', min_delta= 0.01, patience= 3, verbose=1)

mc = ModelCheckpoint(filepath="best_model.h5",
                    monitor= 'val_accuracy',
                    min_delta= 0.01,
                    patience= 3,
                    verbose=1 ,
                    save_best_only= True)

cb = [es,mc]

# %%
his = model.fit(train ,
                steps_per_epoch= 16,
                epochs= 50,
                verbose= 1,
                callbacks= cb ,
                validation_data= val ,
                validation_steps= 16)
# Out:
# Epoch 1/50
# 16/16 [==============================] - ETA: 0s - loss: 7.3226 - accuracy: 0.5586
# Epoch 00001: val_accuracy improved from -inf to 0.84375, saving model to best_model.h5
# 16/16 [==============================] - 279s 15s/step - loss: 7.3226 - accuracy: 0.5586 - val_loss: 1.9046 - val_accuracy: 0.8438
# Epoch 2/50
# 16/16 [==============================] - ETA: 0s - loss: 1.6205 - accuracy: 0.8457
# Epoch 00002: val_accuracy improved from 0.84375 to 0.84961, saving model to best_model.h5
# 16/16 [==============================] - 210s 13s/step - loss: 1.6205 - accuracy: 0.8457 - val_loss: 2.0718 - val_accuracy: 0.8496
# Epoch 3/50
# 16/16 [==============================] - ETA: 0s - loss: 1.3660 - accuracy: 0.8750
# Epoch 00003: val_accuracy improved from 0.84961 to 0.93555, saving model to best_model.h5
# 16/16 [==============================] - 172s 11s/step - loss: 1.3660 - accuracy: 0.8750 - val_loss: 0.7358 - val_accuracy: 0.9355
# Epoch 4/50
# ...

# %% [markdown]
# **Graphs**

# %%
h = his.history
h.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot (h['accuracy'])
plt.plot (h['val_accuracy'], c = "red")
plt.title("acc vs v-acc")
plt.show()

# %%
plt.plot(h['loss'])
plt.plot (h['val_loss'], c = "red")
plt.title("loss vs v-loss")
plt.show()

# %% [markdown]
# **Importing Model and Prediction**

# %%
from keras.models import load_model

model = load_model("/content/best_model.h5")

# %%
print(dict(zip( list(train.class_indices.values()) , list(train.class_indices.keys()) ) ))
ref = dict(zip( list(train.class_indices.values()) , list(train.class_indices.keys()) ) )
# Out:
# {0: 'Apple___Apple_scab', 1: 'Apple___Black_rot', 2: 'Apple___Cedar_apple_rust', 3: 'Apple___healthy'}

# %%
def prediction(path):
  img = load_img(path, target_size = (256,256))
  i = img_to_array(img)
  im = preprocess_input(i)
  img = np.expand_dims(im , axis= 0)
  pred = np.argmax(model.predict(img))
  print(f" the image belongs to { ref[pred] } ")
  #print(model.predict(img))

# %%
path = "/content/test/bacterial_spot.JPG"

prediction(path)
# Out:
#  the image belongs to Tomato___Bacterial_spot
